# %%
# %%capture cap_out --no-stderr

from libitmal import versions as v

v.Versions()

import sys
print(sys.path)
# Out:
# WARNING: library 'sklearn' does not have a '__version__' attribute
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 from libitmal import versions as v
# ----> 3 v.Versions()
#       5 import sys
#       6 print(sys.path)
#
# File ~/GITMAL/libitmal/versions.py:24, in Versions()
#      22 TryPrintVersion("numpy")
#      23 TryPrintVersion("sklearn")
# ---> 24 TryPrintVersion("keras")
#      25 TryPrintVersion("tensorflow")
#      26 TryPrintVersion("tensorflow.keras")
#
# File ~/GITMAL/libitmal/versions.py:12, in Versions.<locals>.TryPrintVersion(libname)
#      10 def TryPrintVersion(libname):
#      11 	try:
# ---> 12 		lib = importlib.import_module(libname)
#      13 		if "__version__" in dir(lib):
#      14 			PrintVer(libname, f"{lib.__version__}")
#
# ...

# %%
var = cap_out.stdout
print(var)

#import time
#time.sleep(30)

#print('hello5')
# Out:
# Python version:              3.8.5.
# Scikit-learn version:        0.23.2.
# Keras version:               2.4.3
# Tensorflow version:          2.2.0
# Tensorflow.keras version:    2.3.0-tf
# ['/home/cef/Temp', '/home/cef/.local/bin', '/home/cef/itmal', '/home/cef/asedarknet/scripts', '/home/cef/Temp', '/opt/anaconda3/lib/python38.zip', '/opt/anaconda3/lib/python3.8', '/opt/anaconda3/lib/python3.8/lib-dynload', '', '/opt/anaconda3/lib/python3.8/site-packages', '/opt/anaconda3/lib/python3.8/site-packages/IPython/extensions', '/home/cef/.ipython', '/home/cef/itmal', '/home/cef/startup']
